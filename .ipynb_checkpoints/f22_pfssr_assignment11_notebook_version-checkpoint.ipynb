# %% [markdown]
# # EPSY 5122: Programming for Social Science Researchers
# ## Assignment 11
# ### Due Tuesday, November 29, 2022 by 2:30pm

# %% [markdown]
# #### Problem 0
#
# If you've made it to this document, you likely already did Problem 0 from the readme.  But just in case, here it is again!
#
# a) Let's watch some videos! I recommend all the videos in this series (for future learning), but we will just focus on two now. Watch the first half of this video (https://www.youtube.com/watch?v=_NrSWLQsDL4&list=PLRqwX-V7Uu6ZF9C0YMKuns9sLDzK6zoiV&index=3) -- just the part about forking, you can ignore pull requests!  Then watch this video:
# https://www.youtube.com/watch?v=yXT1ElMEkW8&list=PLRqwX-V7Uu6ZF9C0YMKuns9sLDzK6zoiV&index=6 (you don't have to do the terminal git commands, you can use the GitKraken clone strategy we used in class)
#
# b) Using what you learned in 0a, **fork** my GitHub repository (remote repo) to your own account, then **clone** to your hard drive (local repo) using GitKraken (or use the command-line if you want the extra challenge).  After finishing EACH problem below, make sure to STAGE and COMMIT with a comment (e.g., "Just finished Part 1! Git is fun!" or whatever).  Then PUSH back to GitHub.

# %% [markdown]
# ###### Note on privacy!
#
# By default, GitHub repos are public (promoting open source sharing of code), but of course you are more than welcome to make your code for this assignment private, as is your right!  Unfortunately, it's a little bit complicated because GitKraken recently made a change that the free version of their software doesn't allow for private repo access, and you need the paid version.  So here are 3 ways to do this privately:
#
# 1) GitKraken partners with GitHub to provide a free pack of resources (including the pro version of GitKraken) for *students*.  That's you!  So you can sign up here *only if you want to do this*: https://education.github.com/pack?utm_source=github+gitkraken
#
# 2) Just keep your GitHub repo public while you're working on this project.  Use free GitKraken.  Then switch the GitHub repo to Private only when you're done using GitKraken to push to GitHub.
#
# 3) Keep the repo private and use the terminal git commands in the YouTube video for Problem 0a.
#
# To make the repo private:
# On your GitHub repo, go to Settings > Manage Access > Manage (under Public Repository) > Change Visibility.  Then add me (jkbye) as a 'collaborator' so I can see it: Settings > Manage Access > Invite a Collaborator (green button) > add 'jkbye'.

# %% [markdown]
# #### Problem 1
#
# Now let's get to Jupyter!
#
# a) Import any helpful libraries in this Jupyter Notebook.
#
# b) Load the *MA_Public_Schools_2017.csv* file as a pandas data frame.  Note: these data are from Kaggle: https://www.kaggle.com/ndalziel/massachusetts-public-schools-data and I have already removed a lot of columns.
#
# c) Adapt the example code in the chunk below to replace all spaces in column names with underscores. This is good practice in order to not cause problems with functions that don't allow spaces in variable names (e.g., **smf.ols**).
#
# d) Adapt the code from 1c to replace "%" sign with "Perc", because it is also good practice not to start column names with symbols.
#
# e) Find the descriptives for numeric columns.
#
# f) Commit your changes and push to GitHub!

# %%
# Problem 1 code here (can split into multiple code chunks if you want)
import pandas as pd
import numpy as np
from statistics import mean, median, mode, stdev

# b)
school_data = pd.read_csv('MA_Public_Schools_2017.csv')

# c)
school_data.columns = school_data.columns.str.replace(' ', '_') 
# notice this replaces the 1st argument w/ the 2nd

# d)
school_data.columns = school_data.columns.str.replace('%', 'Perc')

# e)
for i in range(len(school_data.keys())):
    try:
        mean(school_data[school_data.keys()[i]]) 
        print(school_data[school_data.keys()[i]].describe())
    except TypeError:
        None

#f)
# Out:
# count    1.861000e+03
# mean     2.918442e+06
# std      3.941407e+06
# min      1.000200e+04
# 25%      9.700600e+05
# 50%      2.100410e+06
# 75%      3.310030e+06
# max      3.902090e+07
# Name: School_Code, dtype: float64
# count    1861.000000
# mean     1903.744224
# std       483.331225
# min      1001.000000
# 25%      1560.000000
# 50%      1921.000000
# 75%      2176.000000
# max      2790.000000
# Name: Zip, dtype: float64
# count    1.861000e+03
# mean     2.918254e+06
# std      3.941370e+06
# min      1.000000e+04
# 25%      9.700000e+05
# 50%      2.100000e+06
# 75%      3.310000e+06
# max      3.902000e+07
# Name: District_Code, dtype: float64
# count    1861.000000
# mean       15.837722
# std        37.784512
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%        15.000000
# max       560.000000
# Name: PK_Enrollment, dtype: float64
# count    1861.000000
# mean       35.535196
# std        44.632989
# min         0.000000
# 25%         0.000000
# 50%        17.000000
# 75%        64.000000
# max       557.000000
# Name: K_Enrollment, dtype: float64
# count    1861.000000
# mean       36.629232
# std        42.732414
# min         0.000000
# 25%         0.000000
# 50%        22.000000
# 75%        66.000000
# max       245.000000
# Name: 1_Enrollment, dtype: float64
# count    1861.000000
# mean       37.518538
# std        43.842672
# min         0.000000
# 25%         0.000000
# 50%        20.000000
# 75%        68.000000
# max       250.000000
# Name: 2_Enrollment, dtype: float64
# count    1861.000000
# mean       38.584632
# std        46.541783
# min         0.000000
# 25%         0.000000
# 50%        16.000000
# 75%        71.000000
# max       319.000000
# Name: 3_Enrollment, dtype: float64
# count    1861.000000
# mean       38.717356
# std        48.915559
# min         0.000000
# 25%         0.000000
# 50%        16.000000
# 75%        70.000000
# max       446.000000
# Name: 4_Enrollment, dtype: float64
# count    1861.000000
# mean       38.089199
# std        55.040382
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%        66.000000
# max       487.000000
# Name: 5_Enrollment, dtype: float64
# count    1861.000000
# mean       37.879635
# std        75.304290
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%        45.000000
# max       490.000000
# Name: 6_Enrollment, dtype: float64
# count    1861.000000
# mean       38.543794
# std        81.320657
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%        22.000000
# max       511.000000
# Name: 7_Enrollment, dtype: float64
# count    1861.000000
# mean       38.540570
# std        82.048832
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%        20.000000
# max       644.000000
# Name: 8_Enrollment, dtype: float64
# count    1861.000000
# mean       40.936593
# std       107.149344
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max      1223.000000
# Name: 9_Enrollment, dtype: float64
# count    1861.000000
# mean       39.344976
# std       102.234288
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max      1048.000000
# Name: 10_Enrollment, dtype: float64
# count    1861.000000
# mean       38.301451
# std       100.030758
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max       978.000000
# Name: 11_Enrollment, dtype: float64
# count    1861.000000
# mean       37.290167
# std        96.420554
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max       993.000000
# Name: 12_Enrollment, dtype: float64
# count    1861.000000
# mean        0.743149
# std         3.355883
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max        43.000000
# Name: SP_Enrollment, dtype: float64
# count    1861.000000
# mean      512.492208
# std       366.632205
# min         0.000000
# 25%       294.000000
# 50%       436.000000
# 75%       618.000000
# max      4264.000000
# Name: TOTAL_Enrollment, dtype: float64
# count    1850.000000
# mean      103.764324
# std       167.247214
# min         0.000000
# 25%        11.000000
# 50%        42.000000
# 75%       126.750000
# max      2759.000000
# Name: First_Language_Not_English, dtype: float64
# count    1850.00000
# mean       18.54827
# std        20.03104
# min         0.00000
# 25%         3.20000
# 50%        10.50000
# 75%        27.90000
# max       100.00000
# Name: Perc_First_Language_Not_English, dtype: float64
# count    1850.000000
# mean       48.758919
# std        80.867673
# min         0.000000
# 25%         4.000000
# 50%        16.000000
# 75%        57.750000
# max      1020.000000
# Name: English_Language_Learner, dtype: float64
# count    1850.000000
# mean        9.548432
# std        13.163096
# min         0.000000
# 25%         0.900000
# 50%         3.600000
# 75%        13.200000
# max        82.900000
# Name: Perc_English_Language_Learner, dtype: float64
# count    1850.000000
# mean       84.887568
# std        61.547453
# min         0.000000
# 25%        45.000000
# 50%        70.000000
# 75%       108.000000
# max       589.000000
# Name: Students_With_Disabilities, dtype: float64
# count    1850.000000
# mean       18.223676
# std        11.462500
# min         0.000000
# 25%        12.900000
# 50%        16.100000
# 75%        20.000000
# max       100.000000
# Name: Perc_Students_With_Disabilities, dtype: float64
# count    1850.000000
# mean      230.231351
# std       207.580354
# min         0.000000
# 25%       103.000000
# 50%       169.000000
# 75%       290.750000
# max      2646.000000
# Name: High_Needs, dtype: float64
# count    1850.000000
# mean       46.616216
# std        22.966461
# min         0.000000
# 25%        27.400000
# 50%        41.200000
# 75%        64.975000
# max       100.000000
# Name: Perc_High_Needs, dtype: float64
# count    1850.000000
# mean      155.927027
# std       168.130704
# min         0.000000
# 25%        48.000000
# 50%       102.000000
# 75%       205.000000
# max      1997.000000
# Name: Economically_Disadvantaged, dtype: float64
# count    1850.000000
# mean       31.816649
# std        22.409908
# min         0.000000
# 25%        12.825000
# 50%        25.900000
# 75%        47.800000
# max        94.400000
# Name: Perc_Economically_Disadvantaged, dtype: float64
# count    1850.000000
# mean        8.699459
# std        13.698280
# min         0.000000
# 25%         1.400000
# 50%         3.300000
# 75%         8.700000
# max        86.900000
# Name: Perc_African_American, dtype: float64
# count    1850.000000
# mean        6.050919
# std         8.763984
# min         0.000000
# 25%         1.200000
# 50%         2.600000
# 75%         6.900000
# max        73.700000
# Name: Perc_Asian, dtype: float64
# count    1850.000000
# mean       18.996649
# std        22.575734
# min         0.000000
# 25%         4.000000
# 50%         8.200000
# 75%        27.300000
# max        98.000000
# Name: Perc_Hispanic, dtype: float64
# count    1850.000000
# mean       62.326486
# std        29.562086
# min         0.000000
# 25%        41.000000
# 50%        73.200000
# 75%        86.600000
# max       100.000000
# Name: Perc_White, dtype: float64
# count    1850.000000
# mean        0.233459
# std         0.501732
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.300000
# max         8.000000
# Name: Perc_Native_American, dtype: float64
# count    1850.000000
# mean        0.098000
# std         0.285813
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.100000
# max         6.100000
# Name: Perc_Native_Hawaiian,_Pacific_Islander, dtype: float64
# count    1850.000000
# mean        3.596595
# std         2.420830
# min         0.000000
# 25%         1.900000
# 50%         3.200000
# 75%         4.775000
# max        17.400000
# Name: Perc_Multi-Race,_Non-Hispanic, dtype: float64
# count    1850.000000
# mean       51.899405
# std         5.121577
# min        24.000000
# 25%        49.400000
# 50%        51.400000
# 75%        53.600000
# max       100.000000
# Name: Perc_Males, dtype: float64
# count    1850.000000
# mean       48.095135
# std         5.122469
# min         0.000000
# 25%        46.400000
# 50%        48.600000
# 75%        50.600000
# max        76.000000
# Name: Perc_Females, dtype: float64
# count    1823.000000
# mean      240.532639
# std       207.625544
# min         1.000000
# 25%       100.500000
# 50%       179.000000
# 75%       317.500000
# max      2001.000000
# Name: Total_#_of_Classes, dtype: float64
# count    1823.000000
# mean       18.320570
# std         3.966979
# min         2.000000
# 25%        16.300000
# 50%        18.600000
# 75%        20.800000
# max        41.100000
# Name: Average_Class_Size, dtype: float64
# count    1823.000000
# mean      523.515634
# std       357.861705
# min         2.000000
# 25%       306.500000
# 50%       445.000000
# 75%       634.500000
# max      4327.000000
# Name: Number_of_Students, dtype: float64
# count    1.769000e+03
# mean     5.625178e+07
# std      9.335788e+07
# min      5.534000e+04
# 25%      1.215839e+07
# 50%      2.269741e+07
# 75%      4.808571e+07
# max      3.838662e+08
# Name: Salary_Totals, dtype: float64
# count      1769.000000
# mean      74036.641040
# std        7990.377315
# min       34588.000000
# 25%       68572.000000
# 50%       73471.000000
# 75%       78256.000000
# max      100731.000000
# Name: Average_Salary, dtype: float64
# count    1769.000000
# mean      707.853024
# std      1065.807405
# min         2.000000
# 25%       166.000000
# 50%       308.000000
# 75%       627.000000
# max      4323.000000
# Name: FTE_Count, dtype: float64
# count    1.768000e+03
# mean     1.518097e+08
# std      2.661339e+08
# min      6.975500e+05
# 25%      3.061598e+07
# 50%      5.293331e+07
# 75%      1.287478e+08
# max      1.093104e+09
# Name: In-District_Expenditures, dtype: float64
# count     1768.000000
# mean      9376.335633
# std      14015.732845
# min         38.400000
# 25%       2312.150000
# 50%       4205.300000
# 75%       7700.400000
# max      56858.800000
# Name: Total_In-district_FTEs, dtype: float64
# count     1768.00000
# mean     14573.85582
# std       2940.80342
# min       9451.51000
# 25%      12785.25000
# 50%      13599.49000
# 75%      15478.08000
# max      38780.85000
# Name: Average_In-District_Expenditures_per_Pupil, dtype: float64
# count    1.768000e+03
# mean     1.731198e+08
# std      3.093057e+08
# min      1.132413e+06
# 25%      3.353242e+07
# 50%      5.863741e+07
# 75%      1.335444e+08
# max      1.269580e+09
# Name: Total_Expenditures, dtype: float64
# count     1768.000000
# mean     10466.072624
# std      16287.467986
# min         82.800000
# 25%       2442.900000
# 50%       4392.000000
# 75%       8378.900000
# max      65964.600000
# Name: Total_Pupil_FTEs, dtype: float64
# count     1768.000000
# mean     15038.254949
# std       2743.977057
# min      10399.970000
# 25%      13339.700000
# 50%      14137.480000
# 75%      15900.290000
# max      30505.050000
# Name: Average_Expenditures_per_Pupil, dtype: float64
# count     376.000000
# mean      190.619681
# std       139.728600
# min         6.000000
# 25%        80.000000
# 50%       163.000000
# 75%       271.250000
# max      1013.000000
# Name: #_in_Cohort, dtype: float64
# count    376.000000
# mean      83.327394
# std       21.459396
# min        0.000000
# 25%       82.150000
# 50%       92.250000
# 75%       96.200000
# max      100.000000
# Name: Perc_Graduated, dtype: float64
# count    376.000000
# mean       7.160638
# std       10.682521
# min        0.000000
# 25%        1.400000
# 50%        3.250000
# 75%        7.825000
# max       77.800000
# Name: Perc_Still_in_School, dtype: float64
# count    376.000000
# mean       1.252660
# std        3.532756
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max       30.800000
# Name: Perc_Non-Grad_Completers, dtype: float64
# count    376.000000
# mean       1.127660
# std        2.119165
# min        0.000000
# 25%        0.000000
# 50%        0.500000
# 75%        1.300000
# max       19.000000
# Name: Perc_GED, dtype: float64
# count    376.000000
# mean       7.089362
# std       11.241290
# min        0.000000
# 25%        1.000000
# 50%        2.900000
# 75%        7.900000
# max       71.400000
# Name: Perc_Dropped_Out, dtype: float64
# count    376.000000
# mean       0.042021
# std        0.211004
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.900000
# Name: Perc_Permanently_Excluded, dtype: float64
# count    371.000000
# mean     173.264151
# std      127.717489
# min        1.000000
# 25%       74.000000
# 50%      149.000000
# 75%      259.000000
# max      897.000000
# Name: High_School_Graduates_(#), dtype: float64
# count    344.000000
# mean     142.104651
# std      100.575316
# min        2.000000
# 25%       59.000000
# 50%      127.500000
# 75%      203.250000
# max      682.000000
# Name: Attending_Coll./Univ._(#), dtype: float64
# count    344.000000
# mean      74.505814
# std       16.180191
# min       10.500000
# 25%       68.175000
# 50%       77.800000
# 75%       86.900000
# max      100.000000
# Name: Perc_Attending_College, dtype: float64
# count    344.000000
# mean       0.171221
# std        0.637518
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        6.900000
# Name: Perc_Private_Two-Year, dtype: float64
# count    344.000000
# mean      32.518023
# std       14.422756
# min        0.000000
# 25%       22.500000
# 50%       30.850000
# 75%       41.575000
# max       77.800000
# Name: Perc_Private_Four-Year, dtype: float64
# count    344.000000
# mean      32.147965
# std       22.182473
# min        0.000000
# 25%       16.300000
# 50%       27.600000
# 75%       44.625000
# max      100.000000
# Name: Perc_Public_Two-Year, dtype: float64
# count    344.000000
# mean      35.168023
# std       13.189446
# min        0.000000
# 25%       27.700000
# 50%       36.950000
# 75%       45.000000
# max       67.900000
# Name: Perc_Public_Four-Year, dtype: float64
# count    344.000000
# mean      30.995058
# std       21.791973
# min        0.000000
# 25%       14.600000
# 50%       26.250000
# 75%       43.950000
# max      100.000000
# Name: Perc_MA_Community_College, dtype: float64
# count    344.000000
# mean      12.922384
# std        8.094964
# min        0.000000
# 25%        7.150000
# 50%       12.250000
# 75%       18.200000
# max       50.000000
# Name: Perc_MA_State_University, dtype: float64
# count    344.000000
# mean      13.463953
# std        7.293636
# min        0.000000
# 25%        9.100000
# 50%       13.700000
# 75%       17.800000
# max       38.100000
# Name: Perc_UMass, dtype: float64
# count    302.000000
# mean      83.410596
# std       61.548595
# min        5.000000
# 25%       39.000000
# 50%       68.500000
# 75%      116.500000
# max      444.000000
# Name: AP_One_Test, dtype: float64
# count    302.000000
# mean      48.993377
# std       37.949520
# min        0.000000
# 25%       22.000000
# 50%       40.000000
# 75%       69.250000
# max      275.000000
# Name: AP_Two_Tests, dtype: float64
# count    302.000000
# mean      24.523179
# std       23.458689
# min        0.000000
# 25%        7.000000
# 50%       19.000000
# 75%       37.000000
# max      195.000000
# Name: AP_Three_Tests, dtype: float64
# count    302.000000
# mean       8.751656
# std       11.570723
# min        0.000000
# 25%        1.000000
# 50%        5.000000
# 75%       13.000000
# max      101.000000
# Name: AP_Four_Tests, dtype: float64
# count    302.000000
# mean       3.456954
# std        6.331627
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        4.000000
# max       51.000000
# Name: AP_Five_or_More_Tests, dtype: float64
# count    303.000000
# mean      41.884488
# std       46.140548
# min        0.000000
# 25%       11.000000
# 50%       28.000000
# 75%       55.000000
# max      269.000000
# Name: AP_Score=1, dtype: float64
# count    303.000000
# mean      60.458746
# std       48.369961
# min        0.000000
# 25%       24.000000
# 50%       50.000000
# 75%       77.500000
# max      278.000000
# Name: AP_Score=2, dtype: float64
# count    303.000000
# mean      75.415842
# std       64.734087
# min        0.000000
# 25%       27.500000
# 50%       63.000000
# 75%      115.000000
# max      615.000000
# Name: AP_Score=3, dtype: float64
# count    303.000000
# mean      70.316832
# std       80.967731
# min        0.000000
# 25%       13.000000
# 50%       43.000000
# 75%      101.500000
# max      640.000000
# Name: AP_Score=4, dtype: float64
# count    303.000000
# mean      59.132013
# std       98.061724
# min        0.000000
# 25%        6.000000
# 50%       24.000000
# 75%       64.000000
# max      824.000000
# Name: AP_Score=5, dtype: float64
# count    303.000000
# mean      42.380528
# std       24.531355
# min        0.000000
# 25%       24.300000
# 50%       39.400000
# 75%       58.700000
# max      100.000000
# Name: Perc_AP_Score_1-2, dtype: float64
# count    303.000000
# mean      57.620792
# std       24.529932
# min        0.000000
# 25%       41.300000
# 50%       60.600000
# 75%       75.700000
# max      100.000000
# Name: Perc_AP_Score_3-5, dtype: float64
# count    360.000000
# mean     138.169444
# std      107.575026
# min        1.000000
# 25%       55.750000
# 50%      114.500000
# 75%      203.250000
# max      623.000000
# Name: SAT_Tests_Taken, dtype: float64
# count    332.000000
# mean     496.831325
# std       63.156080
# min      313.000000
# 25%      467.750000
# 50%      506.000000
# 75%      533.000000
# max      703.000000
# Name: Average_SAT_Reading, dtype: float64
# count    332.000000
# mean     482.918675
# std       63.393434
# min      305.000000
# 25%      446.000000
# 50%      490.000000
# 75%      521.250000
# max      688.000000
# Name: Average_SAT_Writing, dtype: float64
# count    332.000000
# mean     507.063253
# std       60.755706
# min      336.000000
# 25%      473.000000
# 50%      514.000000
# 75%      540.000000
# max      741.000000
# Name: Average_SAT_Math, dtype: float64
# count    258.000000
# mean      55.178295
# std       32.157431
# min        4.000000
# 25%       33.000000
# 50%       50.500000
# 75%       70.000000
# max      229.000000
# Name: MCAS_3rdGrade_Math_P+A_#, dtype: float64
# count    258.000000
# mean      73.375969
# std       15.039058
# min       10.000000
# 25%       65.000000
# 50%       76.000000
# 75%       84.000000
# max      100.000000
# Name: Perc_MCAS_3rdGrade_Math_P+A, dtype: float64
# count    258.000000
# mean      30.193798
# std       21.034372
# min        1.000000
# 25%       16.000000
# 50%       26.000000
# 75%       41.000000
# max      164.000000
# Name: MCAS_3rdGrade_Math_A_#, dtype: float64
# count    258.000000
# mean      39.616279
# std       15.921624
# min        3.000000
# 25%       29.000000
# 50%       39.000000
# 75%       50.750000
# max       76.000000
# Name: Perc_MCAS_3rdGrade_Math_A, dtype: float64
# count    258.000000
# mean      24.984496
# std       14.509079
# min        3.000000
# 25%       15.000000
# 50%       22.000000
# 75%       31.750000
# max       94.000000
# Name: MCAS_3rdGrade_Math_P_#, dtype: float64
# count    258.000000
# mean      33.748062
# std        7.986522
# min        8.000000
# 25%       29.000000
# 50%       34.000000
# 75%       39.000000
# max       58.000000
# Name: Perc_MCAS_3rdGrade_Math_P, dtype: float64
# count    258.000000
# mean      12.670543
# std        8.482299
# min        0.000000
# 25%        6.000000
# 50%       11.000000
# 75%       17.000000
# max       46.000000
# Name: MCAS_3rdGrade_Math_NI_#, dtype: float64
# count    258.000000
# mean      18.034884
# std        9.420709
# min        0.000000
# 25%       10.000000
# 50%       17.000000
# 75%       23.750000
# max       45.000000
# Name: Perc_MCAS_3rdGrade_Math_NI, dtype: float64
# count    258.000000
# mean       6.027132
# std        6.433984
# min        0.000000
# 25%        2.000000
# 50%        4.000000
# 75%        8.000000
# max       55.000000
# Name: MCAS_3rdGrade_Math_W/F_#, dtype: float64
# count    258.000000
# mean       8.612403
# std        8.070034
# min        0.000000
# 25%        3.000000
# 50%        6.000000
# 75%       12.000000
# max       46.000000
# Name: Perc_MCAS_3rdGrade_Math_W/F, dtype: float64
# count    258.000000
# mean      73.875969
# std       39.187866
# min       11.000000
# 25%       47.000000
# 50%       69.000000
# 75%       88.000000
# max      276.000000
# Name: MCAS_3rdGrade_Math_Stud._Incl._#, dtype: float64
# count    258.000000
# mean      87.555039
# std        8.476766
# min       54.400000
# 25%       83.300000
# 50%       89.450000
# 75%       94.200000
# max      100.000000
# Name: MCAS_3rdGrade_Math_CPI, dtype: float64
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: MCAS_3rdGrade_Math_SGP, dtype: float64
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: MCAS_3rdGrade_Math_Incl._in_SGP(#), dtype: float64
# count    256.000000
# mean      45.789062
# std       28.721285
# min        2.000000
# 25%       25.000000
# 50%       42.000000
# 75%       61.250000
# max      175.000000
# Name: MCAS_4thGrade_Math_P+A_#, dtype: float64
# count    256.000000
# mean      60.539062
# std       18.769563
# min       14.000000
# 25%       48.000000
# 50%       62.500000
# 75%       75.000000
# max       95.000000
# Name: Perc_MCAS_4thGrade_Math_P+A, dtype: float64
# count    256.000000
# mean      19.718750
# std       15.683106
# min        0.000000
# 25%        7.000000
# 50%       16.000000
# 75%       30.250000
# max       96.000000
# Name: MCAS_4thGrade_Math_A_#, dtype: float64
# count    256.000000
# mean      25.757812
# std       15.918048
# min        0.000000
# 25%       13.000000
# 50%       23.000000
# 75%       36.000000
# max       76.000000
# Name: Perc_MCAS_4thGrade_Math_A, dtype: float64
# count    256.000000
# mean      26.070312
# std       16.482520
# min        2.000000
# 25%       16.000000
# 50%       23.000000
# 75%       31.250000
# max      112.000000
# Name: MCAS_4thGrade_Math_P_#, dtype: float64
# count    256.000000
# mean      34.847656
# std        8.863023
# min       11.000000
# 25%       30.000000
# 50%       35.000000
# 75%       41.000000
# max       61.000000
# Name: Perc_MCAS_4thGrade_Math_P, dtype: float64
# count    256.000000
# mean      22.527344
# std       16.532536
# min        3.000000
# 25%       11.000000
# 50%       18.000000
# 75%       29.000000
# max       90.000000
# Name: MCAS_4thGrade_Math_NI_#, dtype: float64
# count    256.000000
# mean      31.414062
# std       13.875371
# min        4.000000
# 25%       20.000000
# 50%       31.500000
# 75%       41.250000
# max       64.000000
# Name: Perc_MCAS_4thGrade_Math_NI, dtype: float64
# count    256.000000
# mean       5.472656
# std        5.519949
# min        0.000000
# 25%        1.750000
# 50%        4.000000
# 75%        7.000000
# max       31.000000
# Name: MCAS_4thGrade_Math_W/F_#, dtype: float64
# count    256.000000
# mean       8.062500
# std        7.895146
# min        0.000000
# 25%        3.000000
# 50%        6.000000
# 75%       11.000000
# max       47.000000
# Name: Perc_MCAS_4thGrade_Math_W/F, dtype: float64
# count    256.000000
# mean      73.789062
# std       41.658585
# min       11.000000
# 25%       46.000000
# 50%       67.000000
# 75%       88.000000
# max      273.000000
# Name: MCAS_4thGrade_Math_Stud._Incl._#, dtype: float64
# count    256.000000
# mean      84.095703
# std        9.182098
# min       51.100000
# 25%       78.900000
# 50%       86.050000
# 75%       91.000000
# max       98.900000
# Name: MCAS_4thGrade_Math_CPI, dtype: float64
# count    243.000000
# mean      59.376543
# std       15.226499
# min       13.000000
# 25%       50.000000
# 50%       61.000000
# 75%       70.250000
# max       96.500000
# Name: MCAS_4thGrade_Math_SGP, dtype: float64
# count    256.000000
# mean      70.957031
# std       40.519979
# min       11.000000
# 25%       43.000000
# 50%       63.000000
# 75%       85.000000
# max      267.000000
# Name: MCAS_4thGrade_Math_Incl._in_SGP(#), dtype: float64
# count    242.000000
# mean      52.962810
# std       36.062225
# min        5.000000
# 25%       27.250000
# 50%       45.000000
# 75%       68.000000
# max      218.000000
# Name: MCAS_5thGrade_Math_P+A_#, dtype: float64
# count    242.000000
# mean      65.599174
# std       16.543432
# min       11.000000
# 25%       54.250000
# 50%       68.000000
# 75%       78.750000
# max       96.000000
# Name: Perc_MCAS_5thGrade_Math_P+A, dtype: float64
# count    242.000000
# mean      27.061983
# std       21.533152
# min        0.000000
# 25%       11.250000
# 50%       22.000000
# 75%       37.000000
# max      129.000000
# Name: MCAS_5thGrade_Math_A_#, dtype: float64
# count    242.000000
# mean      33.148760
# std       16.502313
# min        0.000000
# 25%       20.250000
# 50%       32.000000
# 75%       44.000000
# max       77.000000
# Name: Perc_MCAS_5thGrade_Math_A, dtype: float64
# count    242.000000
# mean      25.900826
# std       17.592862
# min        4.000000
# 25%       14.000000
# 50%       20.000000
# 75%       32.750000
# max      109.000000
# Name: MCAS_5thGrade_Math_P_#, dtype: float64
# count    242.000000
# mean      32.433884
# std        7.520771
# min       11.000000
# 25%       28.000000
# 50%       32.000000
# 75%       37.000000
# max       57.000000
# Name: Perc_MCAS_5thGrade_Math_P, dtype: float64
# count    242.000000
# mean      18.661157
# std       13.737645
# min        1.000000
# 25%        9.000000
# 50%       14.500000
# 75%       24.750000
# max       87.000000
# Name: MCAS_5thGrade_Math_NI_#, dtype: float64
# count    242.000000
# mean      24.359504
# std       10.566078
# min        4.000000
# 25%       17.000000
# 50%       23.000000
# 75%       32.000000
# max       52.000000
# Name: Perc_MCAS_5thGrade_Math_NI, dtype: float64
# count    242.000000
# mean       7.487603
# std        7.072964
# min        0.000000
# 25%        2.000000
# 50%        6.000000
# 75%       10.000000
# max       39.000000
# Name: MCAS_5thGrade_Math_W/F_#, dtype: float64
# count    242.000000
# mean      10.061983
# std        8.726853
# min        0.000000
# 25%        4.000000
# 50%        8.000000
# 75%       14.000000
# max       62.000000
# Name: Perc_MCAS_5thGrade_Math_W/F, dtype: float64
# count    242.000000
# mean      79.111570
# std       48.638901
# min       12.000000
# 25%       49.250000
# 50%       68.000000
# 75%       91.750000
# max      296.000000
# Name: MCAS_5thGrade_Math_Stud._Incl._#, dtype: float64
# count    242.000000
# mean      84.291322
# std        9.205900
# min       46.700000
# 25%       79.000000
# 50%       86.400000
# 75%       91.150000
# max       98.600000
# Name: MCAS_5thGrade_Math_CPI, dtype: float64
# count    235.000000
# mean      58.753191
# std       13.599300
# min       14.500000
# 25%       50.000000
# 50%       59.000000
# 75%       68.000000
# max       91.000000
# Name: MCAS_5thGrade_Math_SGP, dtype: float64
# count    242.000000
# mean      75.896694
# std       47.482970
# min       12.000000
# 25%       45.250000
# 50%       65.500000
# 75%       88.750000
# max      290.000000
# Name: MCAS_5thGrade_Math_Incl._in_SGP(#), dtype: float64
# count    167.000000
# mean      80.095808
# std       69.519455
# min        5.000000
# 25%       30.500000
# 50%       60.000000
# 75%      104.000000
# max      395.000000
# Name: MCAS_6thGrade_Math_P+A_#, dtype: float64
# count    167.000000
# mean      65.245509
# std       16.498071
# min       26.000000
# 25%       54.000000
# 50%       68.000000
# 75%       78.000000
# max      100.000000
# Name: Perc_MCAS_6thGrade_Math_P+A, dtype: float64
# count    167.000000
# mean      40.628743
# std       43.474337
# min        0.000000
# 25%       12.500000
# 50%       29.000000
# 75%       51.000000
# max      280.000000
# Name: MCAS_6thGrade_Math_A_#, dtype: float64
# count    167.000000
# mean      31.826347
# std       16.816150
# min        0.000000
# 25%       19.000000
# 50%       31.000000
# 75%       43.500000
# max       80.000000
# Name: Perc_MCAS_6thGrade_Math_A, dtype: float64
# count    167.000000
# mean      39.467066
# std       30.616710
# min        3.000000
# 25%       15.000000
# 50%       30.000000
# 75%       56.500000
# max      142.000000
# Name: MCAS_6thGrade_Math_P_#, dtype: float64
# count    167.000000
# mean      33.365269
# std        7.738465
# min       15.000000
# 25%       28.000000
# 50%       34.000000
# 75%       39.000000
# max       58.000000
# Name: Perc_MCAS_6thGrade_Math_P, dtype: float64
# count    167.000000
# mean      25.958084
# std       21.689583
# min        0.000000
# 25%       10.500000
# 50%       22.000000
# 75%       35.500000
# max      159.000000
# Name: MCAS_6thGrade_Math_NI_#, dtype: float64
# count    167.000000
# mean      22.964072
# std       10.782567
# min        0.000000
# 25%       14.500000
# 50%       22.000000
# 75%       29.000000
# max       52.000000
# Name: Perc_MCAS_6thGrade_Math_NI, dtype: float64
# count    167.000000
# mean      13.071856
# std       13.503935
# min        0.000000
# 25%        4.000000
# 50%       10.000000
# 75%       17.000000
# max       84.000000
# Name: MCAS_6thGrade_Math_W/F_#, dtype: float64
# count    167.000000
# mean      11.790419
# std        8.163858
# min        0.000000
# 25%        6.000000
# 50%       10.000000
# 75%       17.000000
# max       37.000000
# Name: Perc_MCAS_6thGrade_Math_W/F, dtype: float64
# count    167.000000
# mean     119.125749
# std       91.189408
# min       12.000000
# 25%       52.000000
# 50%       92.000000
# 75%      169.500000
# max      447.000000
# Name: MCAS_6thGrade_Math_Stud._Incl._#, dtype: float64
# count    167.000000
# mean      83.181437
# std        9.170110
# min       59.800000
# 25%       77.150000
# 50%       85.200000
# 75%       90.200000
# max      100.000000
# Name: MCAS_6thGrade_Math_CPI, dtype: float64
# count    158.000000
# mean      55.025316
# std       15.888825
# min       22.000000
# 25%       44.000000
# 50%       54.000000
# 75%       66.000000
# max       88.000000
# Name: MCAS_6thGrade_Math_SGP, dtype: float64
# count    167.000000
# mean     113.670659
# std       87.870828
# min       12.000000
# 25%       46.000000
# 50%       89.000000
# 75%      160.000000
# max      428.000000
# Name: MCAS_6thGrade_Math_Incl._in_SGP(#), dtype: float64
# count    129.000000
# mean      91.705426
# std       72.807581
# min        1.000000
# 25%       42.000000
# 50%       71.000000
# 75%      113.000000
# max      376.000000
# Name: MCAS_7thGrade_Math_P+A_#, dtype: float64
# count    129.000000
# mean      60.077519
# std       17.318980
# min        6.000000
# 25%       50.000000
# 50%       60.000000
# 75%       73.000000
# max       91.000000
# Name: Perc_MCAS_7thGrade_Math_P+A, dtype: float64
# count    129.000000
# mean      43.589147
# std       44.688612
# min        0.000000
# 25%       17.000000
# 50%       29.000000
# 75%       49.000000
# max      264.000000
# Name: MCAS_7thGrade_Math_A_#, dtype: float64
# count    129.000000
# mean      27.790698
# std       15.420499
# min        0.000000
# 25%       16.000000
# 50%       25.000000
# 75%       36.000000
# max       69.000000
# Name: Perc_MCAS_7thGrade_Math_A, dtype: float64
# count    129.000000
# mean      48.116279
# std       33.314699
# min        1.000000
# 25%       24.000000
# 50%       41.000000
# 75%       61.000000
# max      167.000000
# Name: MCAS_7thGrade_Math_P_#, dtype: float64
# count    129.000000
# mean      32.248062
# std        7.838239
# min        6.000000
# 25%       28.000000
# 50%       32.000000
# 75%       37.000000
# max       57.000000
# Name: Perc_MCAS_7thGrade_Math_P, dtype: float64
# count    129.000000
# mean      36.015504
# std       24.265454
# min        2.000000
# 25%       16.000000
# 50%       32.000000
# 75%       50.000000
# max      138.000000
# Name: MCAS_7thGrade_Math_NI_#, dtype: float64
# count    129.000000
# mean      24.534884
# std        9.189878
# min        6.000000
# 25%       18.000000
# 50%       25.000000
# 75%       31.000000
# max       63.000000
# Name: Perc_MCAS_7thGrade_Math_NI, dtype: float64
# count    129.000000
# mean      21.426357
# std       19.146954
# min        1.000000
# 25%        8.000000
# 50%       16.000000
# 75%       28.000000
# max      113.000000
# Name: MCAS_7thGrade_Math_W/F_#, dtype: float64
# count    129.000000
# mean      15.488372
# std       10.950968
# min        1.000000
# 25%        7.000000
# 50%       12.000000
# 75%       21.000000
# max       55.000000
# Name: Perc_MCAS_7thGrade_Math_W/F, dtype: float64
# count    129.000000
# mean     149.147287
# std       95.811020
# min       16.000000
# 25%       76.000000
# 50%      132.000000
# 75%      199.000000
# max      437.000000
# Name: MCAS_7thGrade_Math_Stud._Incl._#, dtype: float64
# count    129.000000
# mean      79.613953
# std       10.529206
# min       47.900000
# 25%       73.600000
# 50%       80.600000
# 75%       88.000000
# max       96.300000
# Name: MCAS_7thGrade_Math_CPI, dtype: float64
# count    128.000000
# mean      53.824219
# std       11.745428
# min       26.500000
# 25%       45.000000
# 50%       51.500000
# 75%       62.000000
# max       83.000000
# Name: MCAS_7thGrade_Math_SGP, dtype: float64
# count    129.000000
# mean     142.798450
# std       92.512785
# min       13.000000
# 25%       68.000000
# 50%      124.000000
# 75%      193.000000
# max      421.000000
# Name: MCAS_7thGrade_Math_Incl._in_SGP(#), dtype: float64
# count    132.000000
# mean      91.053030
# std       71.519102
# min        0.000000
# 25%       40.000000
# 50%       69.000000
# 75%      121.750000
# max      372.000000
# Name: MCAS_8thGrade_Math_P+A_#, dtype: float64
# count    132.000000
# mean      59.742424
# std       18.792812
# min        0.000000
# 25%       48.750000
# 50%       62.000000
# 75%       74.250000
# max       92.000000
# Name: Perc_MCAS_8thGrade_Math_P+A, dtype: float64
# count    132.000000
# mean      48.643939
# std       46.277809
# min        0.000000
# 25%       19.000000
# 50%       35.000000
# 75%       65.250000
# max      242.000000
# Name: MCAS_8thGrade_Math_A_#, dtype: float64
# count    132.000000
# mean      31.568182
# std       16.355401
# min        0.000000
# 25%       20.000000
# 50%       29.000000
# 75%       43.000000
# max       73.000000
# Name: Perc_MCAS_8thGrade_Math_A, dtype: float64
# count    132.000000
# mean      42.409091
# std       30.267246
# min        0.000000
# 25%       18.000000
# 50%       37.500000
# 75%       55.000000
# max      136.000000
# Name: MCAS_8thGrade_Math_P_#, dtype: float64
# count    132.000000
# mean      28.196970
# std        7.876372
# min        0.000000
# 25%       24.000000
# 50%       29.000000
# 75%       34.000000
# max       45.000000
# Name: Perc_MCAS_8thGrade_Math_P, dtype: float64
# count    132.000000
# mean      34.446970
# std       23.209736
# min        1.000000
# 25%       16.000000
# 50%       29.000000
# 75%       48.500000
# max      100.000000
# Name: MCAS_8thGrade_Math_NI_#, dtype: float64
# count    132.000000
# mean      24.204545
# std        9.519557
# min        4.000000
# 25%       16.000000
# 50%       24.000000
# 75%       31.000000
# max       50.000000
# Name: Perc_MCAS_8thGrade_Math_NI, dtype: float64
# count    132.000000
# mean      20.128788
# std       16.511576
# min        0.000000
# 25%        8.000000
# 50%       16.000000
# 75%       27.000000
# max       78.000000
# Name: MCAS_8thGrade_Math_W/F_#, dtype: float64
# count    132.000000
# mean      16.098485
# std       14.690632
# min        0.000000
# 25%        7.000000
# 50%       13.000000
# 75%       20.000000
# max       92.000000
# Name: Perc_MCAS_8thGrade_Math_W/F, dtype: float64
# count    132.000000
# mean     145.628788
# std       94.266344
# min       10.000000
# 25%       71.500000
# 50%      131.000000
# 75%      200.250000
# max      433.000000
# Name: MCAS_8thGrade_Math_Stud._Incl._#, dtype: float64
# count    132.000000
# mean      78.885606
# std       12.767068
# min       23.100000
# 25%       73.600000
# 50%       81.450000
# 75%       87.725000
# max       97.700000
# Name: MCAS_8thGrade_Math_CPI, dtype: float64
# count    127.000000
# mean      45.248031
# std       14.415720
# min       12.500000
# 25%       36.000000
# 50%       44.000000
# 75%       55.500000
# max       79.000000
# Name: MCAS_8thGrade_Math_SGP, dtype: float64
# count    132.000000
# mean     140.090909
# std       91.934631
# min        9.000000
# 25%       65.250000
# 50%      126.500000
# 75%      195.250000
# max      420.000000
# Name: MCAS_8thGrade_Math_Incl._in_SGP(#), dtype: float64
# count    351.000000
# mean     151.014245
# std      110.913621
# min        2.000000
# 25%       61.500000
# 50%      126.000000
# 75%      222.000000
# max      587.000000
# Name: MCAS_10thGrade_Math_P+A_#, dtype: float64
# count    351.000000
# mean      77.347578
# std       17.717433
# min       10.000000
# 25%       71.000000
# 50%       82.000000
# 75%       90.000000
# max      100.000000
# Name: Perc_MCAS_10thGrade_Math_P+A, dtype: float64
# count    351.000000
# mean     105.632479
# std       89.806738
# min        0.000000
# 25%       37.000000
# 50%       81.000000
# 75%      153.000000
# max      492.000000
# Name: MCAS_10thGrade_Math_A_#, dtype: float64
# count    351.000000
# mean      52.230769
# std       20.954257
# min        0.000000
# 25%       39.000000
# 50%       53.000000
# 75%       68.000000
# max       97.000000
# Name: Perc_MCAS_10thGrade_Math_A, dtype: float64
# count    351.000000
# mean      45.381766
# std       34.187502
# min        1.000000
# 25%       22.000000
# 50%       37.000000
# 75%       59.500000
# max      245.000000
# Name: MCAS_10thGrade_Math_P_#, dtype: float64
# count    351.000000
# mean      25.136752
# std        8.396502
# min        3.000000
# 25%       20.000000
# 50%       25.000000
# 75%       30.000000
# max       55.000000
# Name: Perc_MCAS_10thGrade_Math_P, dtype: float64
# count    351.000000
# mean      26.695157
# std       27.749717
# min        0.000000
# 25%       10.000000
# 50%       17.000000
# 75%       31.000000
# max      221.000000
# Name: MCAS_10thGrade_Math_NI_#, dtype: float64
# count    351.000000
# mean      15.549858
# std       10.475942
# min        0.000000
# 25%        8.000000
# 50%       14.000000
# 75%       21.000000
# max       65.000000
# Name: Perc_MCAS_10thGrade_Math_NI, dtype: float64
# count    351.000000
# mean      11.806268
# std       18.573470
# min        0.000000
# 25%        3.000000
# 50%        6.000000
# 75%       12.000000
# max      136.000000
# Name: MCAS_10thGrade_Math_W/F_#, dtype: float64
# count    351.000000
# mean       7.105413
# std        9.534763
# min        0.000000
# 25%        2.000000
# 50%        4.000000
# 75%        9.000000
# max       80.000000
# Name: Perc_MCAS_10thGrade_Math_W/F, dtype: float64
# count    351.000000
# mean     189.515670
# std      133.377484
# min       10.000000
# 25%       86.000000
# 50%      161.000000
# 75%      287.500000
# max      925.000000
# Name: MCAS_10thGrade_Math_Stud._Incl._#, dtype: float64
# count    351.000000
# mean      89.556125
# std        9.896502
# min       30.000000
# 25%       86.600000
# 50%       92.200000
# 75%       96.000000
# max      100.000000
# Name: MCAS_10thGrade_Math_CPI, dtype: float64
# count    333.000000
# mean      50.575075
# std       12.520480
# min       16.000000
# 25%       42.500000
# 50%       51.000000
# 75%       58.000000
# max       89.500000
# Name: MCAS_10thGrade_Math_SGP, dtype: float64
# count    350.000000
# mean     167.368571
# std      117.365877
# min        1.000000
# 25%       73.250000
# 50%      148.500000
# 75%      249.500000
# max      761.000000
# Name: MCAS_10thGrade_Math_Incl._in_SGP(#), dtype: float64
# count    258.000000
# mean      46.147287
# std       28.660253
# min        5.000000
# 25%       26.250000
# 50%       41.000000
# 75%       61.000000
# max      220.000000
# Name: MCAS_3rdGrade_English_P+A_#, dtype: float64
# count    258.000000
# mean      61.112403
# std       15.920491
# min       12.000000
# 25%       51.250000
# 50%       62.000000
# 75%       73.000000
# max       94.000000
# Name: Perc_MCAS_3rdGrade_English_P+A, dtype: float64
# count    258.00000
# mean       7.98062
# std        7.79227
# min        0.00000
# 25%        3.00000
# 50%        6.00000
# 75%       11.75000
# max       74.00000
# Name: MCAS_3rdGrade_English_A_#, dtype: float64
# count    258.000000
# mean      10.236434
# std        7.127679
# min        0.000000
# 25%        5.000000
# 50%        9.000000
# 75%       14.000000
# max       36.000000
# Name: Perc_MCAS_3rdGrade_English_A, dtype: float64
# count    258.000000
# mean      38.166667
# std       22.630670
# min        4.000000
# 25%       22.000000
# 50%       35.000000
# 75%       50.750000
# max      168.000000
# Name: MCAS_3rdGrade_English_P_#, dtype: float64
# count    258.000000
# mean      50.899225
# std       12.086810
# min       10.000000
# 25%       45.000000
# 50%       52.000000
# 75%       59.000000
# max       84.000000
# Name: Perc_MCAS_3rdGrade_English_P, dtype: float64
# count    258.000000
# mean      23.445736
# std       14.003577
# min        0.000000
# 25%       13.250000
# 50%       20.000000
# 75%       30.000000
# max       87.000000
# Name: MCAS_3rdGrade_English_NI_#, dtype: float64
# count    258.000000
# mean      32.604651
# std       12.520438
# min        0.000000
# 25%       23.250000
# 50%       32.000000
# 75%       41.000000
# max       74.000000
# Name: Perc_MCAS_3rdGrade_English_NI, dtype: float64
# count    258.000000
# mean       4.472868
# std        4.834341
# min        0.000000
# 25%        1.000000
# 50%        3.000000
# 75%        6.000000
# max       39.000000
# Name: MCAS_3rdGrade_English_W/F_#, dtype: float64
# count    258.000000
# mean       6.286822
# std        6.211191
# min        0.000000
# 25%        2.000000
# 50%        4.000000
# 75%        9.000000
# max       30.000000
# Name: Perc_MCAS_3rdGrade_English_W/F, dtype: float64
# count    258.000000
# mean      74.065891
# std       39.195007
# min       11.000000
# 25%       48.000000
# 50%       69.000000
# 75%       88.000000
# max      276.000000
# Name: MCAS_3rdGrade_English_Stud._Incl._#, dtype: float64
# count    258.000000
# mean      85.063566
# std        7.641683
# min       55.500000
# 25%       80.800000
# 50%       86.050000
# 75%       90.900000
# max       98.500000
# Name: MCAS_3rdGrade_English_CPI, dtype: float64
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: MCAS_3rdGrade_English_SGP, dtype: float64
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: MCAS_3rdGrade_English_Incl._in_SGP(#), dtype: float64
# count    256.000000
# mean      48.132812
# std       28.360805
# min        3.000000
# 25%       26.750000
# 50%       44.000000
# 75%       63.000000
# max      177.000000
# Name: MCAS_4thGrade_English_P+A_#, dtype: float64
# count    256.000000
# mean      64.500000
# std       16.002696
# min       14.000000
# 25%       54.000000
# 50%       66.000000
# 75%       77.000000
# max       96.000000
# Name: Perc_MCAS_4thGrade_English_P+A, dtype: float64
# count    256.000000
# mean       8.691406
# std        7.275697
# min        0.000000
# 25%        3.000000
# 50%        7.000000
# 75%       13.000000
# max       34.000000
# Name: MCAS_4thGrade_English_A_#, dtype: float64
# count    256.000000
# mean      11.945312
# std        8.905877
# min        0.000000
# 25%        5.000000
# 50%       10.000000
# 75%       17.000000
# max       45.000000
# Name: Perc_MCAS_4thGrade_English_A, dtype: float64
# count    256.000000
# mean      39.441406
# std       23.822803
# min        3.000000
# 25%       22.000000
# 50%       37.000000
# 75%       50.000000
# max      145.000000
# Name: MCAS_4thGrade_English_P_#, dtype: float64
# count    256.000000
# mean      52.546875
# std       11.194088
# min       14.000000
# 25%       46.000000
# 50%       54.000000
# 75%       60.000000
# max       74.000000
# Name: Perc_MCAS_4thGrade_English_P, dtype: float64
# count    256.000000
# mean      19.167969
# std       14.209604
# min        2.000000
# 25%       10.000000
# 50%       15.000000
# 75%       24.250000
# max       91.000000
# Name: MCAS_4thGrade_English_NI_#, dtype: float64
# count    256.000000
# mean      26.261719
# std       10.330891
# min        4.000000
# 25%       18.000000
# 50%       26.000000
# 75%       33.000000
# max       53.000000
# Name: Perc_MCAS_4thGrade_English_NI, dtype: float64
# count    256.000000
# mean       6.574219
# std        6.923841
# min        0.000000
# 25%        2.000000
# 50%        5.000000
# 75%        9.000000
# max       42.000000
# Name: MCAS_4thGrade_English_W/F_#, dtype: float64
# count    256.000000
# mean       9.238281
# std        8.346060
# min        0.000000
# 25%        3.000000
# 50%        7.000000
# 75%       13.000000
# max       55.000000
# Name: Perc_MCAS_4thGrade_English_W/F, dtype: float64
# count    256.000000
# mean      73.875000
# std       41.600339
# min       11.000000
# 25%       46.000000
# 50%       67.000000
# 75%       88.250000
# max      269.000000
# Name: MCAS_4thGrade_English_Stud._Incl._#, dtype: float64
# count    256.000000
# mean      84.158203
# std        8.811152
# min       38.600000
# 25%       78.875000
# 50%       85.450000
# 75%       90.500000
# max       98.600000
# Name: MCAS_4thGrade_English_CPI, dtype: float64
# count    244.000000
# mean      57.256148
# std       12.249085
# min       17.000000
# 25%       49.000000
# 50%       58.500000
# 75%       66.000000
# max       89.000000
# Name: MCAS_4thGrade_English_SGP, dtype: float64
# count    256.000000
# mean      70.847656
# std       40.372921
# min       11.000000
# 25%       43.000000
# 50%       64.000000
# 75%       86.000000
# max      264.000000
# Name: MCAS_4thGrade_English_Incl._in_SGP(#), dtype: float64
# count    242.000000
# mean      57.483471
# std       36.542276
# min        7.000000
# 25%       33.000000
# 50%       49.000000
# 75%       73.000000
# max      230.000000
# Name: MCAS_5thGrade_English_P+A_#, dtype: float64
# count    242.000000
# mean      72.301653
# std       14.716544
# min       30.000000
# 25%       64.000000
# 50%       74.500000
# 75%       84.000000
# max       97.000000
# Name: Perc_MCAS_5thGrade_English_P+A, dtype: float64
# count    242.000000
# mean      19.260331
# std       15.688963
# min        0.000000
# 25%        7.000000
# 50%       15.000000
# 75%       29.000000
# max       89.000000
# Name: MCAS_5thGrade_English_A_#, dtype: float64
# count    242.000000
# mean      23.826446
# std       14.437835
# min        0.000000
# 25%       13.000000
# 50%       20.000000
# 75%       33.000000
# max       64.000000
# Name: Perc_MCAS_5thGrade_English_A, dtype: float64
# count    242.000000
# mean      38.223140
# std       25.150497
# min        7.000000
# 25%       23.000000
# 50%       32.000000
# 75%       43.750000
# max      160.000000
# Name: MCAS_5thGrade_English_P_#, dtype: float64
# count    242.000000
# mean      48.491736
# std        9.353031
# min       23.000000
# 25%       42.000000
# 50%       50.000000
# 75%       55.000000
# max       71.000000
# Name: Perc_MCAS_5thGrade_English_P, dtype: float64
# count    242.000000
# mean      17.247934
# std       14.547836
# min        1.000000
# 25%        8.000000
# 50%       12.000000
# 75%       22.000000
# max       86.000000
# Name: MCAS_5thGrade_English_NI_#, dtype: float64
# count    242.000000
# mean      22.061983
# std       11.103076
# min        1.000000
# 25%       13.000000
# 50%       20.500000
# 75%       29.750000
# max       55.000000
# Name: Perc_MCAS_5thGrade_English_NI, dtype: float64
# count    242.000000
# mean       4.462810
# std        4.923551
# min        0.000000
# 25%        1.000000
# 50%        2.500000
# 75%        7.000000
# max       31.000000
# Name: MCAS_5thGrade_English_W/F_#, dtype: float64
# count    242.000000
# mean       5.657025
# std        5.619517
# min        0.000000
# 25%        1.250000
# 50%        4.000000
# 75%        8.000000
# max       31.000000
# Name: Perc_MCAS_5thGrade_English_W/F, dtype: float64
# count    242.000000
# mean      79.194215
# std       48.758354
# min       12.000000
# 25%       49.000000
# 50%       68.000000
# 75%       92.000000
# max      298.000000
# Name: MCAS_5thGrade_English_Stud._Incl._#, dtype: float64
# count    242.000000
# mean      88.795868
# std        6.964729
# min       64.800000
# 25%       85.000000
# 50%       90.250000
# 75%       94.200000
# max       99.300000
# Name: MCAS_5thGrade_English_CPI, dtype: float64
# count    236.000000
# mean      51.158898
# std       13.543907
# min       18.000000
# 25%       41.375000
# 50%       50.000000
# 75%       60.000000
# max       93.500000
# Name: MCAS_5thGrade_English_SGP, dtype: float64
# count    242.000000
# mean      75.714876
# std       47.372162
# min       12.000000
# 25%       45.000000
# 50%       65.500000
# 75%       88.000000
# max      293.000000
# Name: MCAS_5thGrade_English_Incl._in_SGP(#), dtype: float64
# count    167.000000
# mean      91.119760
# std       76.193223
# min        8.000000
# 25%       35.000000
# 50%       66.000000
# 75%      126.000000
# max      410.000000
# Name: MCAS_6thGrade_English_P+A_#, dtype: float64
# count    167.000000
# mean      74.682635
# std       13.584226
# min       36.000000
# 25%       67.000000
# 50%       78.000000
# 75%       85.000000
# max       95.000000
# Name: Perc_MCAS_6thGrade_English_P+A, dtype: float64
# count    167.000000
# mean      28.514970
# std       31.416145
# min        1.000000
# 25%        8.000000
# 50%       18.000000
# 75%       36.500000
# max      172.000000
# Name: MCAS_6thGrade_English_A_#, dtype: float64
# count    167.000000
# mean      22.311377
# std       12.264605
# min        1.000000
# 25%       13.000000
# 50%       21.000000
# 75%       29.500000
# max       70.000000
# Name: Perc_MCAS_6thGrade_English_A, dtype: float64
# count    167.000000
# mean      62.604790
# std       48.607967
# min        6.000000
# 25%       23.000000
# 50%       50.000000
# 75%       90.500000
# max      238.000000
# Name: MCAS_6thGrade_English_P_#, dtype: float64
# count    167.000000
# mean      52.341317
# std        8.492216
# min       23.000000
# 25%       47.000000
# 50%       52.000000
# 75%       58.000000
# max       81.000000
# Name: Perc_MCAS_6thGrade_English_P, dtype: float64
# count    167.000000
# mean      20.341317
# std       17.039208
# min        1.000000
# 25%        8.000000
# 50%       15.000000
# 75%       29.500000
# max       96.000000
# Name: MCAS_6thGrade_English_NI_#, dtype: float64
# count    167.000000
# mean      18.149701
# std        9.198369
# min        1.000000
# 25%       11.000000
# 50%       17.000000
# 75%       24.000000
# max       48.000000
# Name: Perc_MCAS_6thGrade_English_NI, dtype: float64
# count    167.000000
# mean       7.808383
# std        8.249815
# min        0.000000
# 25%        2.000000
# 50%        5.000000
# 75%       10.000000
# max       40.000000
# Name: MCAS_6thGrade_English_W/F_#, dtype: float64
# count    167.000000
# mean       7.203593
# std        6.217483
# min        0.000000
# 25%        3.000000
# 50%        5.000000
# 75%       10.000000
# max       33.000000
# Name: Perc_MCAS_6thGrade_English_W/F, dtype: float64
# count    167.000000
# mean     119.269461
# std       91.247079
# min       12.000000
# 25%       52.000000
# 50%       92.000000
# 75%      169.500000
# max      446.000000
# Name: MCAS_6thGrade_English_Stud._Incl._#, dtype: float64
# count    167.000000
# mean      88.861677
# std        7.207474
# min       62.700000
# 25%       85.050000
# 50%       91.100000
# 75%       94.000000
# max       98.900000
# Name: MCAS_6thGrade_English_CPI, dtype: float64
# count    159.000000
# mean      47.103774
# std       12.457532
# min       19.500000
# 25%       38.250000
# 50%       46.500000
# 75%       54.500000
# max       84.500000
# Name: MCAS_6thGrade_English_SGP, dtype: float64
# count    167.000000
# mean     113.646707
# std       87.736742
# min       12.000000
# 25%       46.500000
# 50%       90.000000
# 75%      160.500000
# max      427.000000
# Name: MCAS_6thGrade_English_Incl._in_SGP(#), dtype: float64
# count    129.000000
# mean     123.108527
# std       85.480374
# min       12.000000
# 25%       60.000000
# 50%       98.000000
# 75%      162.000000
# max      409.000000
# Name: MCAS_7thGrade_English_P+A_#, dtype: float64
# count    129.000000
# mean      81.728682
# std       11.357646
# min       38.000000
# 25%       75.000000
# 50%       84.000000
# 75%       91.000000
# max       99.000000
# Name: Perc_MCAS_7thGrade_English_P+A, dtype: float64
# count    129.000000
# mean      24.426357
# std       25.119332
# min        0.000000
# 25%        9.000000
# 50%       17.000000
# 75%       30.000000
# max      121.000000
# Name: MCAS_7thGrade_English_A_#, dtype: float64
# count    129.000000
# mean      15.434109
# std        9.378204
# min        0.000000
# 25%        8.000000
# 50%       14.000000
# 75%       20.000000
# max       48.000000
# Name: Perc_MCAS_7thGrade_English_A, dtype: float64
# count    129.000000
# mean      98.682171
# std       65.310913
# min       12.000000
# 25%       51.000000
# 50%       85.000000
# 75%      126.000000
# max      319.000000
# Name: MCAS_7thGrade_English_P_#, dtype: float64
# count    129.000000
# mean      66.294574
# std        8.925388
# min       37.000000
# 25%       62.000000
# 50%       68.000000
# 75%       72.000000
# max       86.000000
# Name: Perc_MCAS_7thGrade_English_P, dtype: float64
# count    129.000000
# mean      21.217054
# std       15.560849
# min        1.000000
# 25%        8.000000
# 50%       18.000000
# 75%       30.000000
# max       75.000000
# Name: MCAS_7thGrade_English_NI_#, dtype: float64
# count    129.000000
# mean      14.736434
# std        8.563658
# min        1.000000
# 25%        8.000000
# 50%       14.000000
# 75%       20.000000
# max       45.000000
# Name: Perc_MCAS_7thGrade_English_NI, dtype: float64
# count    129.000000
# mean       5.201550
# std        6.733057
# min        0.000000
# 25%        1.000000
# 50%        3.000000
# 75%        7.000000
# max       53.000000
# Name: MCAS_7thGrade_English_W/F_#, dtype: float64
# count    129.000000
# mean       3.558140
# std        3.962533
# min        0.000000
# 25%        1.000000
# 50%        2.000000
# 75%        5.000000
# max       29.000000
# Name: Perc_MCAS_7thGrade_English_W/F, dtype: float64
# count    129.000000
# mean     149.527132
# std       95.877043
# min       15.000000
# 25%       76.000000
# 50%      133.000000
# 75%      199.000000
# max      438.000000
# Name: MCAS_7thGrade_English_Stud._Incl._#, dtype: float64
# count    129.000000
# mean      92.913953
# std        5.162769
# min       69.700000
# 25%       89.700000
# 50%       94.100000
# 75%       96.900000
# max       99.600000
# Name: MCAS_7thGrade_English_CPI, dtype: float64
# count    128.000000
# mean      62.851562
# std       10.245483
# min       31.000000
# 25%       56.000000
# 50%       63.000000
# 75%       70.000000
# max       89.000000
# Name: MCAS_7thGrade_English_SGP, dtype: float64
# count    129.000000
# mean     143.023256
# std       92.475205
# min       14.000000
# 25%       68.000000
# 50%      124.000000
# 75%      193.000000
# max      419.000000
# Name: MCAS_7thGrade_English_Incl._in_SGP(#), dtype: float64
# count    132.000000
# mean     123.643939
# std       85.430489
# min        1.000000
# 25%       57.500000
# 50%      108.000000
# 75%      161.750000
# max      422.000000
# Name: MCAS_8thGrade_English_P+A_#, dtype: float64
# count    132.000000
# mean      82.628788
# std       14.708571
# min        8.000000
# 25%       78.000000
# 50%       86.500000
# 75%       91.250000
# max      100.000000
# Name: Perc_MCAS_8thGrade_English_P+A, dtype: float64
# count    132.000000
# mean      30.363636
# std       30.723160
# min        0.000000
# 25%        9.000000
# 50%       18.000000
# 75%       43.250000
# max      146.000000
# Name: MCAS_8thGrade_English_A_#, dtype: float64
# count    132.000000
# mean      19.181818
# std       12.055735
# min        0.000000
# 25%        9.750000
# 50%       17.500000
# 75%       27.250000
# max       51.000000
# Name: Perc_MCAS_8thGrade_English_A, dtype: float64
# count    132.000000
# mean      93.280303
# std       60.396440
# min        1.000000
# 25%       44.750000
# 50%       86.500000
# 75%      124.500000
# max      276.000000
# Name: MCAS_8thGrade_English_P_#, dtype: float64
# count    132.000000
# mean      63.446970
# std       11.106228
# min        8.000000
# 25%       59.000000
# 50%       65.000000
# 75%       70.000000
# max       82.000000
# Name: Perc_MCAS_8thGrade_English_P, dtype: float64
# count    132.000000
# mean      16.151515
# std       12.731811
# min        0.000000
# 25%        7.000000
# 50%       13.000000
# 75%       22.000000
# max       54.000000
# Name: MCAS_8thGrade_English_NI_#, dtype: float64
# count    132.000000
# mean      12.454545
# std        9.532078
# min        0.000000
# 25%        6.000000
# 50%       10.500000
# 75%       16.250000
# max       67.000000
# Name: Perc_MCAS_8thGrade_English_NI, dtype: float64
# count    132.000000
# mean       6.068182
# std        6.502135
# min        0.000000
# 25%        1.000000
# 50%        4.500000
# 75%        8.000000
# max       39.000000
# Name: MCAS_8thGrade_English_W/F_#, dtype: float64
# count    132.000000
# mean       4.939394
# std        7.068647
# min        0.000000
# 25%        1.000000
# 50%        3.000000
# 75%        6.000000
# max       64.000000
# Name: Perc_MCAS_8thGrade_English_W/F, dtype: float64
# count    132.000000
# mean     145.863636
# std       94.279572
# min       10.000000
# 25%       72.000000
# 50%      130.500000
# 75%      200.250000
# max      437.000000
# Name: MCAS_8thGrade_English_Stud._Incl._#, dtype: float64
# count    132.000000
# mean      92.428030
# std        7.875765
# min       43.200000
# 25%       90.500000
# 50%       94.500000
# 75%       96.650000
# max      100.000000
# Name: MCAS_8thGrade_English_CPI, dtype: float64
# count    127.000000
# mean      54.681102
# std        9.586629
# min       30.000000
# 25%       47.250000
# 50%       55.000000
# 75%       61.000000
# max       81.000000
# Name: MCAS_8thGrade_English_SGP, dtype: float64
# count    132.000000
# mean     139.840909
# std       91.550414
# min        9.000000
# 25%       65.750000
# 50%      124.500000
# 75%      194.250000
# max      421.000000
# Name: MCAS_8thGrade_English_Incl._in_SGP(#), dtype: float64
# count    353.000000
# mean     174.872521
# std      124.489563
# min        2.000000
# 25%       76.000000
# 50%      148.000000
# 75%      259.000000
# max      813.000000
# Name: MCAS_10thGrade_English_P+A_#, dtype: float64
# count    353.000000
# mean      91.348442
# std       10.626690
# min       13.000000
# 25%       89.000000
# 50%       95.000000
# 75%       98.000000
# max      100.000000
# Name: Perc_MCAS_10thGrade_English_P+A, dtype: float64
# count    353.000000
# mean      91.093484
# std       81.098318
# min        0.000000
# 25%       28.000000
# 50%       65.000000
# 75%      131.000000
# max      441.000000
# Name: MCAS_10thGrade_English_A_#, dtype: float64
# count    353.000000
# mean      44.730878
# std       21.668305
# min        0.000000
# 25%       28.000000
# 50%       45.000000
# 75%       62.000000
# max       90.000000
# Name: Perc_MCAS_10thGrade_English_A, dtype: float64
# count    353.000000
# mean      83.779037
# std       65.375071
# min        2.000000
# 25%       39.000000
# 50%       67.000000
# 75%      112.000000
# max      480.000000
# Name: MCAS_10thGrade_English_P_#, dtype: float64
# count    353.000000
# mean      46.626062
# std       15.904959
# min        9.000000
# 25%       34.000000
# 50%       46.000000
# 75%       59.000000
# max       85.000000
# Name: Perc_MCAS_10thGrade_English_P, dtype: float64
# count    353.000000
# mean       9.949008
# std       13.662436
# min        0.000000
# 25%        2.000000
# 50%        5.000000
# 75%       11.000000
# max       97.000000
# Name: MCAS_10thGrade_English_NI_#, dtype: float64
# count    353.000000
# mean       6.266289
# std        7.583057
# min        0.000000
# 25%        1.000000
# 50%        4.000000
# 75%        8.000000
# max       60.000000
# Name: Perc_MCAS_10thGrade_English_NI, dtype: float64
# count    353.000000
# mean       3.957507
# std        6.658121
# min        0.000000
# 25%        0.000000
# 50%        2.000000
# 75%        4.000000
# max       43.000000
# Name: MCAS_10thGrade_English_W/F_#, dtype: float64
# count    353.000000
# mean       2.390935
# std        4.115537
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        3.000000
# max       44.000000
# Name: Perc_MCAS_10thGrade_English_W/F, dtype: float64
# count    353.000000
# mean     188.779037
# std      133.556197
# min       10.000000
# 25%       83.000000
# 50%      162.000000
# 75%      286.000000
# max      925.000000
# Name: MCAS_10thGrade_English_Stud._Incl._#, dtype: float64
# count    353.000000
# mean      96.725212
# std        4.378358
# min       60.000000
# 25%       96.000000
# 50%       98.100000
# 75%       99.300000
# max      100.000000
# Name: MCAS_10thGrade_English_CPI, dtype: float64
# count    333.000000
# mean      50.834835
# std       11.730844
# min       25.500000
# 25%       42.500000
# 50%       50.000000
# 75%       58.500000
# max       88.000000
# Name: MCAS_10thGrade_English_SGP, dtype: float64
# count    352.000000
# mean     166.062500
# std      117.261301
# min        1.000000
# 25%       69.750000
# 50%      148.000000
# 75%      249.250000
# max      757.000000
# Name: MCAS_10thGrade_English_Incl._in_SGP(#), dtype: float64
# count    1541.000000
# mean       51.690461
# std        28.271634
# min         1.000000
# 25%        28.000000
# 50%        52.000000
# 75%        76.000000
# max        99.000000
# Name: School_Accountability_Percentile_(1-99), dtype: float64
# count    1591.000000
# mean       72.283470
# std        16.149793
# min        27.000000
# 25%        61.000000
# 50%        71.000000
# 75%        84.000000
# max       100.000000
# Name: Progress_and_Performance_Index_(PPI)_-_All_Students, dtype: float64
# count    1489.000000
# mean       68.751511
# std        15.507587
# min        19.000000
# 25%        58.000000
# 50%        68.000000
# 75%        79.000000
# max       100.000000
# Name: Progress_and_Performance_Index_(PPI)_-_High_Needs_Students, dtype: float64
# count    1828.000000
# mean       64.840810
# std        14.365711
# min        36.000000
# 25%        54.000000
# 50%        62.000000
# 75%        71.000000
# max       100.000000
# Name: District_Progress_and_Performance_Index_(PPI)_-_All_Students, dtype: float64
# count    1812.000000
# mean       59.611479
# std        11.458433
# min        32.000000
# 25%        53.000000
# 50%        57.000000
# 75%        65.000000
# max       100.000000
# Name: District_Progress_and_Performance_Index_(PPI)_-_High_Needs_Students, dtype: float64

# %% [markdown]
# #### Problem 2
#
# a) Remove the District Code column.
#
# b) Create a new column called "TOTAL_Enrollment" that is the sum of all columns that end in "Enrollment".
#
# c) Compute the mean of "TOTAL_Enrollment" for each District. (Hint: groupby)
#
# d) Commit your changes and push to GitHub!

# %%
# Problem 2 code here (can split into multiple code chunks if you want)

# %% [markdown]
# #### Problem 3
#
# a) Visualize each bivariate relationship among Average_Class_Size, Average_Salary, Perc_Economically_Disadvantaged, and Perc_English_Language_Learner.  Use the Seaborn function **pairplot**.  The argument to `pairplot` should be `school_data[['Average_Class_Size', 'Average_Salary', 'Perc_Economically_Disadvantaged', 'Perc_English_Language_Learner']]`, which will just pull those columns out from the full data frame.
#
# b) Describe what you see from the plots.
#
# c) Based on your observations from 3b, and as a completely post-hoc, exploratory analysis, choose one of the 4 measures from 3a to be an outcome variable, and a second measure to be a predictor variable.  Then run a linear regression, print the *summary*, and write a sentence interpreting the results (does not need to be detailed, just practice retrieving the relevant info on predictor significance, etc.)
#
# d) Commit your changes and push to GitHub!

# %%
# Problem 3 code here (can split into multiple code chunks if you want)

# %% [markdown]
# #### Problem 4
#
# a) Create a new linear regression model that takes the model from 3c and adds both of the remaining variables from 3a as additional predictor variables.  To do this, the formula interface would look like `"outcome_name ~ predictor1_name + predictor2_name + predictor3_name"`
#
# b) Print the summary from 4a, and write a short interpretation of the results, especially comparing it to Problem 3c.
#
# c) Add School_Type as another predictor to your model.  Interpret the new predictor in your output.  How is it different from the other predictors?
#
# d) Commit your changes and push to GitHub!

# %%
# Problem 4 code here (can split into multiple code chunks if you want)

# %% [markdown]
# #### Problem 5
#
# a) Save this Jupyter notebook as an HTML file (File > Download As > HTML) into your local repository (this folder). By default, Jupyter may put your HTML file in your default Downloads folder (wherever that is) -- if that happens, just manually move the file into this repo folder.
#
# b) Stage, commit, and push all changes to your GitHub repository.
#
# c) Submit a link to your repository as your submission for the assignment on Canvas. Remember the note from Problem 0: you can keep your repo private and add me as a collaborator.
